# %%
import json
import os
import math
import librosa

data = {
    "mapping": [],
    "labels": [],
    "mfcc": []
}

DATASET_PATH = "/content/drive/MyDrive/genres_original"
JSON_PATH = "data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    folders = os.listdir(dataset_path)
    i=1
    for genre in folders:
      genre_path = os.path.join(dataset_path,genre)
      files = os.listdir(genre_path)
      data["mapping"].append(genre)
      print("\nProcessing: {}".format(genre))
      for f in files:
        file_path = os.path.join(genre_path, f)
        try:

          signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)


          print('Using file:{}'.format(file_path))

          for d in range(num_segments):


              start = samples_per_segment * d
              finish = start + samples_per_segment
              segment = signal[start:finish]


              mfcc = librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
              mfcc = mfcc.T


              if len(mfcc) == num_mfcc_vectors_per_segment:
                  data["mfcc"].append(mfcc.tolist())
                  data["labels"].append(i-1)
        except:
          print('Unable to read : {}\n\n'.format(file_path))

      i = i + 1

if __name__ == "__main__":
    save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Processing: jazz
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00004.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00002.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00005.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00000.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00003.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00001.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00015.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00006.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00009.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00016.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00011.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00007.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00014.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00012.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00018.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00017.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00013.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00008.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00010.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00026.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00030.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00019.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00021.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00027.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00020.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00022.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00031.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00028.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00025.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00029.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00024.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00023.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00039.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00043.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00032.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00042.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00038.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00041.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00036.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00040.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00037.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00033.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00034.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00035.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00055.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00050.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00052.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00053.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00044.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00049.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00045.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00048.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00056.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00051.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00057.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00046.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00047.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00064.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00070.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00062.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00058.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00060.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00067.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00068.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00065.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00066.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00061.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00059.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00069.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00063.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00076.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00082.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00074.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00079.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00081.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00072.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00078.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00075.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00083.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00077.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00071.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00073.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00080.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00090.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00085.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00096.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00084.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00095.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00088.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00089.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00086.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00093.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00092.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00091.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00094.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00087.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00098.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00099.wav
# Using file:/content/drive/MyDrive/genres_original/jazz/jazz.00097.wav
# Unable to read : /content/drive/MyDrive/genres_original/jazz/.ipynb_checkpoints
#
#
#
# Processing: metal
# <ipython-input-1-a3dc26a2f491>:53: UserWarning: PySoundFile failed. Trying audioread instead.
#   signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00009.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00004.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00007.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00001.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00002.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00000.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00006.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00003.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00008.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00005.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00023.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00021.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00013.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00012.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00014.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00011.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00015.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00010.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00020.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00016.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00019.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00018.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00017.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00022.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00035.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00031.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00037.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00029.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00027.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00032.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00036.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00028.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00034.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00033.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00024.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00025.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00026.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00030.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00043.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00047.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00048.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00050.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00045.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00051.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00049.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00039.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00044.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00041.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00046.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00042.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00040.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00038.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00054.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00057.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00055.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00063.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00060.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00052.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00056.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00053.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00061.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00062.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00064.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00058.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00059.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00070.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00073.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00071.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00065.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00078.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00075.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00068.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00074.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00069.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00077.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00072.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00066.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00067.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00076.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00082.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00088.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00084.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00086.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00081.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00091.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00092.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00090.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00079.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00080.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00083.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00089.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00087.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00085.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.00095.wav
# Using file:/content/drive/MyDrive/genres_original/metal/metal.
wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00027.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00017.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00019.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00021.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00030.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00031.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00033.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00039.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00037.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00029.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00036.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00034.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00035.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00032.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00040.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00038.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00028.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00047.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00043.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00050.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00046.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00051.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00041.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00048.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00042.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00049.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00045.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00052.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00044.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00065.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00056.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00054.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00060.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00053.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00058.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00066.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00057.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00063.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00055.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00059.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00061.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00062.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00064.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00070.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00068.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00073.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00078.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00076.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00074.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00077.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00072.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00071.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00075.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00069.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00080.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00079.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00067.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00090.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00089.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00091.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00083.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00081.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00082.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00086.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00088.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00092.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00087.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00084.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00093.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00085.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00097.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00098.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00094.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00099.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00095.wav
# Using file:/content/drive/MyDrive/genres_original/hiphop/hiphop.00096.wav

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras

DATA_PATH = "/content/data_10.json"

def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)


    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y


if __name__ == "__main__":

    X, y = load_data(DATA_PATH)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    model = keras.Sequential([

        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        keras.layers.Dense(512, activation='relu'),

        keras.layers.Dense(256, activation='relu'),

        keras.layers.Dense(64, activation='relu'),


        keras.layers.Dense(10, activation='softmax')
    ])


    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# path to json file that stores MFCCs and genre labels for each processed segment
DATA_PATH = "/content/data_10.json"

def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


if __name__ == "__main__":

    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # build network topology
    model = keras.Sequential([

        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),


        keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),


        keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        keras.layers.Dense(10, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100)

    # plot accuracy and error as a function of the epochs
    plot_history(history)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "/content/data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):


    X, y = load_data(DATA_PATH)


    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)


    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):


    model = keras.Sequential()

    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())


    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())


    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())


    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))


    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


def predict(model, X, y):


    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)


    prediction = model.predict(X)

    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

DATA_PATH = "/content/data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):

    model = keras.Sequential()


    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))


    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
